# %%
import pickle as pk

with open("result\\2023-06-17-12-28-25\\metrics.pkl", "rb") as f:
    metrics = pk.load(f)

data = metrics["data"]
data
# Out:
# array([[  1.     , 307.     ,   1.06489],
#        [ 21.     , 299.     ,   1.0651 ],
#        [ 41.     , 294.     ,   1.06553],
#        ...,
#        [  0.     ,   0.     ,   0.     ],
#        [  0.     ,   0.     ,   0.     ],
#        [  0.     ,   0.     ,   0.     ]])

# %%
ppg = data[:, 1]
ppg
# Out:
# array([307., 299., 294., ...,   0.,   0.,   0.])

# %%
import matplotlib.pyplot as plt
plt.plot(ppg)
